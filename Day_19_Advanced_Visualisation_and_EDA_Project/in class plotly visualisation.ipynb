# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import plotly.express as px

# %%
pip install --upgrade ipython nbformat

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.set(style='whitegrid')

# %%
sns.set_theme(
    style="whitegrid",
    context="talk",
    rc={
        "figure.figsize": (8, 4),
        "figure.dpi": 120,
        "axes.titlesize": 16,
        "axes.labelsize": 13,
        "lines.linewidth": 3,
        "lines.linestyle": "-.",
        "legend.frameon": False,
    }
)

# %%
tips = sns.load_dataset('tips')

sns.boxplot(
    data=tips,
    x="day",
    y="tip"
)

plt.title("Tip Distribution by Day")
plt.show()

# %%
# rc parameters
# runtime configurations
plt.rcParams['figure.figsize'] = (10, 7)
plt.rcParams['lines.linewidth'] = 3
plt.rcParams['lines.linestyle'] = '--'
plt.rcParams[]

# %%
sns.pairplot(tips, )

# %%
sns.set(style='whitegrid')

# %%
sns.pairplot(tips,hue = 'time' )
# rc parameters
# runtime configurations
plt.rcParams['figure.figsize'] = (10, 7)
plt.rcParams['lines.linewidth'] = 3
plt.rcParams['lines.linestyle'] = '--'

# %%
#join plot
sns.jointplot(tips, x='total_bill', y='tip', kind='kde', fill = True )

# %%
sns.boxenplot(tips, x= , y ='total_bill' )

# %%
sns.countplot(tips, x = 'day', hue= 'time')
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
#dpi will define the pixel density

# %%
# plotly
import plotly.express as px

barplot = px.bar(tips, x= 'day', y= 'total_bill')

barplot.show()

# %%
# how will you plot mean for everyday
mean_by_day.plot(kind="bar")

plt.title("Average Total Bill by Day")
plt.xlabel("Day")
plt.ylabel("Mean Total Bill")
plt.show()

# %%
bill_by_day.head()
# Out:
#     day  total_bill
# 0  Thur   17.682742
# 1   Fri   17.151579
# 2   Sat   20.441379
# 3   Sun   21.410000

# %%
import seaborn as sns

tips = sns.load_dataset("tips")

bill_by_day = tips.groupby('day', as_index=False)['total_bill'].mean()
bill_by_day
# Out:
# C:\Users\60197\AppData\Local\Temp\ipykernel_11128\3883728871.py:5: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#     day  total_bill
# 0  Thur   17.682742
# 1   Fri   17.151579
# 2   Sat   20.441379
# 3   Sun   21.410000

# %%
# group by any of the categorical columns
# aggregation

tips_by_day = tips.groupby('day')['total_bill'].count()
tips_by_day

tips_by_day = tips.groupby('sex')['total_bill'].max()
tips_by_day
# Out:
# C:\Users\60197\AppData\Local\Temp\ipykernel_11128\360602435.py:4: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# C:\Users\60197\AppData\Local\Temp\ipykernel_11128\360602435.py:7: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# sex
# Male      50.81
# Female    44.30
# Name: total_bill, dtype: float64

# %%
# group by any of the categorical columns
tips_by_days = tips.groupby('day')
tips_by_day[0]

# %%
# create a bar plot of the average tip by each gender
# plotly
import plotly.express as px

barplot = px.bar(
    bill_by_day,
    x='day',
    y='total_bill'
)

barplot.show()

# %%
tips_by_day = tips.groupby('sex')['total_bill'].max()
tips_by_day

bill_by_day = tips.groupby('day', as_index=False)['total_bill'].mean()
bill_by_day

tips.head()
# Out:
# C:\Users\60197\AppData\Local\Temp\ipykernel_11128\1567238035.py:1: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# C:\Users\60197\AppData\Local\Temp\ipykernel_11128\1567238035.py:4: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# craete a bar plot of the average tip by each gender
avg_tip_by_gender = tips.groupby('sex', as_index=False)['tip'].mean()

barplot = px.bar(
    avg_tip_by_gender,
    x='sex',
    y='tip',
    title="Average Tip by Gender"
)

barplot.show()
# Out:
# C:\Users\60197\AppData\Local\Temp\ipykernel_11128\3705521938.py:2: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
scatterbilltip = px.scatter(
    tips,
    x='total_bill',
    y='tip',
    size='size',
    color='day',
    hover_data=['sex', 'smoker', 'time'],

)

scatterbilltip.show()
