# %% [markdown]
# What is Python?
#
# Python is a programming language that is:
#
# * Easy to read and write
# * Popular for Data Analysis, AI, Machine Learning, Web, Automation
# *Very suitable for beginners

# %% [markdown]
# Why use Python?
#
# ✅ Simple, English-like syntax
#
# ✅ Many free libraries
#
# ✅ Used by big companies (Google, Netflix, NASA)
#
# ✅ Great for IT, Data, and AI careers

# %% [markdown]
# What is Python used for?
#
# 📊 Data Analysis (pandas, numpy)
#
# 🤖 Machine Learning & AI
#
# 🌐 Web development
#
# ⚙ Automation / scripting
#
# 🔐 Cybersecurity tools

# %%
# Basic Python Example

print("Hello, World!")
# Out:
# Hello, World!

# %%
# Variable Example

name = "Ida"
age = 23
print(name, age)
# Out:
# Ida 23

# %%
usename=input('Idah')
print ('Welcome to Phython:')
# Out:
# Welcome to Phython:

# %%
print(f'12 (num1) and 13 (num2) Result: (25)')
# Out:
# 12 (num1) and 13 (num2) Result: (25)

# %%
num=int(input ('Enter 2'))
snum=int (input('Enter 5'))
result=fnum+snum
print(f'Result after adding (fnum) and (snum) is = \t (result)')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 num=int(input ('Enter 2'))
#       2 snum=int (input('Enter 5'))
# ----> 3 result=fnum+snum
#       4 print(f'Result after adding (fnum) and (snum) is = \t (result)')
#
# NameError: name 'fnum' is not defined
