# %% [markdown]
# A simple ML workflow:
#
# 1.Problem – What do we want to predict?
# 2.Data – Collect & clean data (you already learned EDA / cleaning).
# 3.Split – Train/Test split.
# 4.Choose a model – e.g., Decision Tree for classification.
# 5.Train – Fit the model on training data.
# 6.Predict – Make predictions on test data.
# 7.Evaluate – Compute metrics (accuracy, etc.).
# 8.Improve – Try better features, models, parameters.
#
# Today we’ll walk through this with a simple example.

# %% [markdown]
# ### Problem
#
# Problem
# * signal
#
# * Iris
#
# * features 5 - 4 input features - 1 target feature
#
# * 150 rows - 50 for each specie
#
# * a machine, model, that predicts species of a flower, by just knowing about
#
#     * < x1,x2,x3,x4 > ---> X ( petal_length )
#     * < y > ---> y (species)
#
# Libraries we know:
#
# * numpy pandas matplotlib seaborn plotly sklearn

# %%
pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.datasets import load_iris

# %%
import pandas as pd

from sklearn.datasets import load_iris

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score, confusion_matrix

# %% [markdown]
# 2. Data
# * data acquisition (sklearn)
# * EDA (data is clean)
#    * cleaning
#    * -> Visualization - insights
# * feature selection

# %%
from sklearn.datasets import load_iris

# %%
from sklearn.datasets import load_iris
import pandas as pd

iris = load_iris()
X = iris.data
y = iris.target

df_X = pd.DataFrame(X, columns=iris.feature_names)
df_y = pd.DataFrame(y, columns=['target'])

# %%
iris = load_iris()

# type(iris

# feature selection
X = iris.data # x1 x2 x3 x4
y = iris.target  # y

X , y = iris.data, iris.target
y

# %%
X = pd.DataFrame(X , columns = iris.feature_names)

y = pd.DataFrame(y)

# df_y = pd.DataFrame(y)
# df_X['species'] = df_y

# df_X.info()
# df_X.describe()
# df_X.isnull().sum()

# %% [markdown]
# 3. Train Test Split
# * train = 80% used for training
# * test = 20% used for testing

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test            =             train_test_split(X,y)

# %%
y_train

# %%
# total 150

len(X_train) # 112 # x1 , x2 , x3 , x4

len(y_train) # 112 # y

len(X_test) # 38 # x1 , x2 , x3 , x4

len(y_test) # 38 # y

# %% [markdown]
# 4. Modeling
# * select model - Linear Regression

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

# %% [markdown]
# 5. Training
# * Fit my training data into Linear Regression
# * X_train, y_train
# * try to learn and identify patterns

# %%
model = LinearRegression()
model.fit(X_train, y_train)

# %%
y_prediction = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix

from sklearn.metrics import mean_absolute_error, r2_score


mae =mean_absolute_error(y_test, y_prediction)

mae

# closer it is to zero, better the performance
# “Minor differences in evaluation metrics may occur due to random data splitting and floating-point precision. These variations do not indicate an error in the model.”

# %%
df_X.head()

# %%
irisdf = pd.concat([df_X, df_y], axis=1)
irisdf.head()

# %% [markdown]
# ML Try to train a linear regression model
#
# * mean absolute error for each case
# * on 15 data records (5 records per species), check mean_absolute_error
# * on 45 data records (15 records per species), check mean_absolute_error
# * on 90 data records (30 records per species), check mean_absolute_error
# * on 150 data records (50 records per species), check mean_absolute_error

# %%
train_test_split

# %%
# data 
from sklearn.datasets import load_iris
iris = load_iris()

X = iris.data # x1 x2 x3
y = iris.target  # y

# split data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y)

# choose a model
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# train the model
model.fit(X_train, y_train)

# test
y_pred = model.predict(X_test)

from sklearn.metrics import mean_absolute_error, r2_score
mae = mean_absolute_error(y_test, y_pred)
mae

r2 = r2_score(y_test, y_pred)
r2

# %%
model.predict([[4.3 , 3.8, 2.4, 0.1]])
